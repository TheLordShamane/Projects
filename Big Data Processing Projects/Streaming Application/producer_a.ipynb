# %% [markdown]
# # Camera Event Producer A
#
# This notebook implements a Kafka producer that reads data from `camera_event_A.csv` and sends it to a Kafka topic in batches.

# %%
# Import required libraries
import pandas as pd
import json
import time
from kafka import KafkaProducer
from datetime import datetime
import os

# %%
# Configuration parameters
KAFKA_BOOTSTRAP_SERVERS = '172.25.240.1:9092'
KAFKA_TOPIC = 'camera_events'
BATCH_INTERVAL = 5  # seconds between each batch
PRODUCER_ID = 'Producer-A'
CSV_FILE = 'camera_event_A.csv'  # Path to the CSV file

# Check if the file exists, otherwise use a default path for testing
if not os.path.exists(CSV_FILE):
    CSV_FILE = '/home/student/Assignment 2/temp_data/data/camera_event_A.csv'  # Adjust path as needed for testing
    if not os.path.exists(CSV_FILE):
        print(f"Warning: {CSV_FILE} not found. Please ensure the file exists.")

# %%
# Function to load data from CSV file
def load_data(file_path):
    try:
        df = pd.read_csv(file_path)
        print(f"Successfully loaded {len(df)} records from {file_path}")
        return df
    except Exception as e:
        print(f"Error loading data: {e}")
        return None

# %%
# Function to initialize Kafka producer
def create_kafka_producer():
    try:
        producer = KafkaProducer(
            bootstrap_servers=KAFKA_BOOTSTRAP_SERVERS,
            value_serializer=lambda v: json.dumps(v).encode('utf-8'),
            key_serializer=lambda k: k.encode('utf-8') if k else None
        )
        print("Kafka producer initialized successfully")
        return producer
    except Exception as e:
        print(f"Error creating Kafka producer: {e}")
        return None

# %%
# Function to process and send data in batches
def process_and_send_batches(producer, df):
    # Get unique batch IDs and sort them
    batch_ids = sorted(df['batch_id'].unique())
    
    for batch_id in batch_ids:
        # Get records for current batch
        batch_df = df[df['batch_id'] == batch_id].copy()
        
        # Add producer information
        batch_df['producer_info'] = PRODUCER_ID
        
        # Add current processing timestamp
        batch_df['processing_timestamp'] = datetime.now().isoformat()
        
        # Extract event date from timestamp
        batch_df['event_date'] = pd.to_datetime(batch_df['timestamp']).dt.date.astype(str)
        
        # Convert to list of dictionaries for sending
        batch_records = batch_df.to_dict('records')
        
        # Send each record in the batch to Kafka
        sent_count = 0
        for record in batch_records:
            try:
                # Use car_plate as the key for partitioning
                key = record['car_plate']
                # Send to Kafka topic
                producer.send(KAFKA_TOPIC, key=key, value=record)
                sent_count += 1
            except Exception as e:
                print(f"Error sending record: {e}")
        
        # Flush to ensure all messages are sent before waiting
        producer.flush()
        
        print(f"Sent batch {batch_id} with {sent_count}/{len(batch_records)} records from {PRODUCER_ID}")
        
        # Wait for the specified interval before sending the next batch
        time.sleep(BATCH_INTERVAL)

# %%
# Main execution function
def run_producer():
    # Load data from CSV
    df = load_data(CSV_FILE)
    if df is None:
        print("Failed to load data. Exiting.")
        return
    
    # Create Kafka producer
    producer = create_kafka_producer()
    if producer is None:
        print("Failed to create Kafka producer. Exiting.")
        return
    
    try:
        # Process and send data in batches
        print(f"Starting to send data from {PRODUCER_ID} at {datetime.now()}")
        process_and_send_batches(producer, df)
        print(f"Finished sending all data from {PRODUCER_ID} at {datetime.now()}")
    except KeyboardInterrupt:
        print("Producer interrupted by user")
    except Exception as e:
        print(f"Error in producer: {e}")
    finally:
        # Close producer
        if producer is not None:
            producer.close()
            print("Kafka producer closed")

# %%
# Run the producer
if __name__ == "__main__":
    run_producer()
# Out:
# Successfully loaded 556340 records from /home/student/Assignment 2/temp_data/data/camera_event_A.csv
# Kafka producer initialized successfully
# Starting to send data from Producer-A at 2025-05-29 10:07:53.968425
# Sent batch 1 with 20/20 records from Producer-A
# Sent batch 2 with 20/20 records from Producer-A
# Sent batch 3 with 20/20 records from Producer-A
# Sent batch 4 with 20/20 records from Producer-A
# Sent batch 5 with 20/20 records from Producer-A
# Sent batch 6 with 20/20 records from Producer-A
# Sent batch 7 with 20/20 records from Producer-A
# Sent batch 8 with 20/20 records from Producer-A
# Sent batch 9 with 20/20 records from Producer-A
# Sent batch 10 with 20/20 records from Producer-A
# Sent batch 11 with 20/20 records from Producer-A
# Sent batch 12 with 20/20 records from Producer-A
# Sent batch 13 with 20/20 records from Producer-A
# Sent batch 14 with 20/20 records from Producer-A
# Sent batch 15 with 20/20 records from Producer-A
# Sent batch 16 with 20/20 records from Producer-A
# Sent batch 17 with 20/20 records from Producer-A
# Sent batch 18 with 20/20 records from Producer-A
# Sent batch 19 with 20/20 records from Producer-A
# Sent batch 20 with 20/20 records from Producer-A
# Sent batch 21 with 20/20 records from Producer-A
# Sent batch 22 with 20/20 records from Producer-A
# Sent batch 23 with 20/20 records from Producer-A
# Sent batch 24 with 20/20 records from Producer-A
# Sent batch 25 with 20/20 records from Producer-A
# Sent batch 26 with 20/20 records from Producer-A
# Sent batch 27 with 20/20 records from Producer-A
# Sent batch 28 with 20/20 records from Producer-A
# Sent batch 29 with 20/20 records from Producer-A
# Sent batch 30 with 20/20 records from Producer-A
# Sent batch 31 with 20/20 records from Producer-A
# Sent batch 32 with 20/20 records from Producer-A
# Sent batch 33 with 20/20 records from Producer-A
# Sent batch 34 with 20/20 records from Producer-A
# Sent batch 35 with 20/20 records from Producer-A
# Sent batch 36 with 20/20 records from Producer-A
# Sent batch 37 with 20/20 records from Producer-A
# Sent batch 38 with 20/20 records from Producer-A
# Sent batch 39 with 20/20 records from Producer-A
# Sent batch 40 with 20/20 records from Producer-A
# Sent batch 41 with 20/20 records from Producer-A
# Sent batch 42 with 20/20 records from Producer-A
# Sent batch 43 with 20/20 records from Producer-A
# Sent batch 44 with 20/20 records from Producer-A
# Sent batch 45 with 20/20 records from Producer-A
# Sent batch 46 with 20/20 records from Producer-A
# Sent batch 47 with 20/20 records from Producer-A
# Sent batch 48 with 20/20 records from Producer-A
# Sent batch 49 with 20/20 records from Producer-A
# Sent batch 50 with 20/20 records from Producer-A
# Sent batch 51 with 20/20 records from Producer-A
# Sent batch 52 with 20/20 records from Producer-A
# Sent batch 53 with 20/20 records from Producer-A
# Sent batch 54 with 20/20 records from Producer-A
# Sent batch 55 with 20/20 records from Producer-A
# Sent batch 56 with 20/20 records from Producer-A
# Sent batch 57 with 20/20 records from Producer-A
# Sent batch 58 with 20/20 records from Producer-A
# Sent batch 59 with 20/20 records from Producer-A
# Sent batch 60 with 20/20 records from Producer-A
# Sent batch 61 with 20/20 records from Producer-A
# Sent batch 62 with 20/20 records from Producer-A
# Sent batch 63 with 20/20 records from Producer-A
# Sent batch 64 with 20/20 records from Producer-A
# Sent batch 65 with 20/20 records from Producer-A
# Sent batch 66 with 20/20 records from Producer-A
# Sent batch 67 with 20/20 records from Producer-A
# Sent batch 68 with 20/20 records from Producer-A
# Sent batch 69 with 20/20 records from Producer-A
# Sent batch 70 with 20/20 records from Producer-A
# Sent batch 71 with 20/20 records from Producer-A
# Sent batch 72 with 20/20 records from Producer-A
# Sent batch 73 with 20/20 records from Producer-A
# Sent batch 74 with 20/20 records from Producer-A
# Sent batch 75 with 20/20 records from Producer-A
# Sent batch 76 with 20/20 records from Producer-A
# Sent batch 77 with 20/20 records from Producer-A
# Sent batch 78 with 20/20 records from Producer-A
# Sent batch 79 with 20/20 records from Producer-A
# Sent batch 80 with 20/20 records from Producer-A
# Sent batch 81 with 20/20 records from Producer-A
# Sent batch 82 with 20/20 records from Producer-A
# Sent batch 83 with 20/20 records from Producer-A
# Sent batch 84 with 20/20 records from Producer-A
# Sent batch 85 with 20/20 records from Producer-A
# Sent batch 86 with 20/20 records from Producer-A
# Sent batch 87 with 20/20 records from Producer-A
# Sent batch 88 with 20/20 records from Producer-A
# Sent batch 89 with 20/20 records from Producer-A
# Sent batch 90 with 20/20 records from Producer-A
# Sent batch 91 with 20/20 records from Producer-A
# Sent batch 92 with 20/20 records from Producer-A
# Sent batch 93 with 20/20 records from Producer-A
# Sent batch 94 with 20/20 records from Producer-A
# Sent batch 95 with 20/20 records from Producer-A
# Sent batch 96 with 20/20 records from Producer-A
# Sent batch 97 with 20/20 records from Producer-A
# Sent batch 98 with 20/20 records from Producer-A
# Sent batch 99 with 20/20 records from Producer-A
# Sent batch 100 with 20/20 records from Producer-A
# Sent batch 101 with 20/20 records from Producer-A
# Sent batch 102 with 20/20 records from Producer-A
# Sent batch 103 with 20/20 records from Producer-A
# Sent batch 104 with 20/20 records from Producer-A
# Sent batch 105 with 20/20 records from Producer-A
# Sent batch 106 with 20/20 records from Producer-A
# Sent batch 107 with 20/20 records from Producer-A
# Sent batch 108 with 20/20 records from Producer-A
# Sent batch 109 with 20/20 records from Producer-A
# Sent batch 110 with 20/20 records from Producer-A
# Sent batch 111 with 20/20 records from Producer-A
# Sent batch 112 with 20/20 records from Producer-A
# Sent batch 113 with 20/20 records from Producer-A
# Sent batch 114 with 20/20 records from Producer-A
# Sent batch 115 with 20/20 records from Producer-A
# Sent batch 116 with 20/20 records from Producer-A
# Sent batch 117 with 20/20 records from Producer-A
# Sent batch 118 with 20/20 records from Producer-A
# Sent batch 119 with 20/20 records from Producer-A
# Sent batch 120 with 20/20 records from Producer-A
# Sent batch 121 with 20/20 records from Producer-A
# Sent batch 122 with 20/20 records from Producer-A
# Sent batch 123 with 20/20 records from Producer-A
# Sent batch 124 with 20/20 records from Producer-A
# Sent batch 125 with 20/20 records from Producer-A
# Sent batch 126 with 20/20 records from Producer-A
# Sent batch 127 with 20/20 records from Producer-A
# Sent batch 128 with 20/20 records from Producer-A
# Sent batch 129 with 20/20 records from Producer-A
# Sent batch 130 with 20/20 records from Producer-A
# Sent batch 131 with 20/20 records from Producer-A
# Sent batch 132 with 20/20 records from Producer-A
# Sent batch 133 with 20/20 records from Producer-A
# Sent batch 134 with 20/20 records from Producer-A
# Sent batch 135 with 20/20 records from Producer-A
# Sent batch 136 with 20/20 records from Producer-A
# Sent batch 137 with 20/20 records from Producer-A
# Sent batch 138 with 20/20 records from Producer-A
# Sent batch 139 with 20/20 records from Producer-A
# Sent batch 140 with 20/20 records from Producer-A
# Sent batch 141 with 20/20 records from Producer-A
# Sent batch 142 with 20/20 records from Producer-A
# Sent batch 143 with 20/20 records from Producer-A
# Sent batch 144 with 20/20 records from Producer-A
# Sent batch 145 with 20/20 records from Producer-A
# Sent batch 146 with 20/20 records from Producer-A
# Sent batch 147 with 20/20 records from Producer-A
# Sent batch 148 with 20/20 records from Producer-A
# Sent batch 149 with 20/20 records from Producer-A
# Sent batch 150 with 20/20 records from Producer-A
# Sent batch 151 with 20/20 records from Producer-A
# Sent batch 152 with 20/20 records from Producer-A
# Sent batch 153 with 20/20 records from Producer-A
# Sent batch 154 with 20/20 records from Producer-A
# Sent batch 155 with 20/20 records from Producer-A
# Sent batch 156 with 20/20 records from Producer-A
# Sent batch 157 with 20/20 records from Producer-A
# Sent batch 158 with 20/20 records from Producer-A
# Sent batch 159 with 20/20 records from Producer-A
# Sent batch 160 with 20/20 records from Producer-A
# Sent batch 161 with 20/20 records from Producer-A
# Sent batch 162 with 20/20 records from Producer-A
# Sent batch 163 with 20/20 records from Producer-A
# Sent batch 164 with 20/20 records from Producer-A
# Sent batch 165 with 20/20 records from Producer-A
# Sent batch 166 with 20/20 records from Producer-A
# Sent batch 167 with 20/20 records from Producer-A
# Sent batch 168 with 20/20 records from Producer-A
# Sent batch 169 with 20/20 records from Producer-A
# Sent batch 170 with 20/20 records from Producer-A
# Sent batch 171 with 20/20 records from Producer-A
# Sent batch 172 with 20/20 records from Producer-A
# Sent batch 173 with 20/20 records from Producer-A
# Sent batch 174 with 20/20 records from Producer-A
# Sent batch 175 with 20/20 records from Producer-A
# Sent batch 176 with 20/20 records from Producer-A
# Sent batch 177 with 20/20 records from Producer-A
# Sent batch 178 with 20/20 records from Producer-A
# Sent batch 179 with 20/20 records from Producer-A
# Sent batch 180 with 20/20 records from Producer-A
# Sent batch 181 with 20/20 records from Producer-A
# Sent batch 182 with 20/20 records from Producer-A
# Sent batch 183 with 20/20 records from Producer-A
# Sent batch 184 with 20/20 records from Producer-A
# Sent batch 185 with 20/20 records from Producer-A
# Sent batch 186 with 20/20 records from Producer-A
# Sent batch 187 with 20/20 records from Producer-A
# Sent batch 188 with 20/20 records from Producer-A
# Sent batch 189 with 20/20 records from Producer-A
# Sent batch 190 with 20/20 records from Producer-A
# Sent batch 191 with 20/20 records from Producer-A
# Sent batch 192 with 20/20 records from Producer-A
# Sent batch 193 with 20/20 records from Producer-A
# Sent batch 194 with 20/20 records from Producer-A
# Sent batch 195 with 20/20 records from Producer-A
# Sent batch 196 with 20/20 records from Producer-A
# Sent batch 197 with 20/20 records from Producer-A
# Sent batch 198 with 20/20 records from Producer-A
# Sent batch 199 with 20/20 records from Producer-A
# Sent batch 200 with 20/20 records from Producer-A
# Sent batch 201 with 20/20 records from Producer-A
# Sent batch 202 with 20/20 records from Producer-A
# Sent batch 203 with 20/20 records from Producer-A
# Sent batch 204 with 20/20 records from Producer-A
# Sent batch 205 with 20/20 records from Producer-A
# Sent batch 206 with 20/20 records from Producer-A
# Sent batch 207 with 20/20 records from Producer-A
# Sent batch 208 with 20/20 records from Producer-A
# Sent batch 209 with 20/20 records from Producer-A
# Sent batch 210 with 20/20 records from Producer-A
# Sent batch 211 with 20/20 records from Producer-A
# Sent batch 212 with 20/20 records from Producer-A
# Sent batch 213 with 20/20 records from Producer-A
# Sent batch 214 with 20/20 records from Producer-A
# Sent batch 215 with 20/20 records from Producer-A
# Sent batch 216 with 20/20 records from Producer-A
# Sent batch 217 with 20/20 records from Producer-A
# Sent batch 218 with 20/20 records from Producer-A
# Sent batch 219 with 20/20 records from Producer-A
# Sent batch 220 with 20/20 records from Producer-A
# Sent batch 221 with 20/20 records from Producer-A
# Sent batch 222 with 20/20 records from Producer-A
# Sent batch 223 with 20/20 records from Producer-A
# Sent batch 224 with 20/20 records from Producer-A
# Sent batch 225 with 20/20 records from Producer-A
# Sent batch 226 with 20/20 records from Producer-A
# Sent batch 227 with 20/20 records from Producer-A
# Sent batch 228 with 20/20 records from Producer-A
# Sent batch 229 with 20/20 records from Producer-A
# Sent batch 230 with 20/20 records from Producer-A
# Sent batch 231 with 20/20 records from Producer-A
# Sent batch 232 with 20/20 records from Producer-A
# Sent batch 233 with 20/20 records from Producer-A
# Sent batch 234 with 20/20 records from Producer-A
# Sent batch 235 with 20/20 records from Producer-A
# Sent batch 236 with 20/20 records from Producer-A
# Sent batch 237 with 20/20 records from Producer-A
# Sent batch 238 with 20/20 records from Producer-A
# Sent batch 239 with 20/20 records from Producer-A
# Sent batch 240 with 20/20 records from Producer-A
# Sent batch 241 with 20/20 records from Producer-A
# Sent batch 242 with 20/20 records from Producer-A
# Sent batch 243 with 20/20 records from Producer-A
# Sent batch 244 with 20/20 records from Producer-A
# Sent batch 245 with 20/20 records from Producer-A
# Sent batch 246 with 20/20 records from Producer-A
# Sent batch 247 with 20/20 records from Producer-A
# Sent batch 248 with 20/20 records from Producer-A
# Sent batch 249 with 20/20 records from Producer-A
# Sent batch 250 with 20/20 records from Producer-A
# Sent batch 251 with 20/20 records from Producer-A
# Sent batch 252 with 20/20 records from Producer-A
# Sent batch 253 with 20/20 records from Producer-A
# Sent batch 254 with 20/20 records from Producer-A
# Sent batch 255 with 20/20 records from Producer-A
# Sent batch 256 with 20/20 records from Producer-A
# Sent batch 257 with 20/20 records from Producer-A
# Sent batch 258 with 20/20 records from Producer-A
# Sent batch 259 with 20/20 records from Producer-A
# Sent batch 260 with 20/20 records from Producer-A
# Sent batch 261 with 20/20 records from Producer-A
# Sent batch 262 with 20/20 records from Producer-A
# Sent batch 263 with 20/20 records from Producer-A
# Sent batch 264 with 20/20 records from Producer-A
# Sent batch 265 with 20/20 records from Producer-A
# Sent batch 266 with 20/20 records from Producer-A
# Sent batch 267 with 20/20 records from Producer-A
# Sent batch 268 with 20/20 records from Producer-A
# Sent batch 269 with 20/20 records from Producer-A
# Sent batch 270 with 20/20 records from Producer-A
# Sent batch 271 with 20/20 records from Producer-A
# Sent batch 272 with 20/20 records from Producer-A
# Sent batch 273 with 20/20 records from Producer-A
# Sent batch 274 with 20/20 records from Producer-A
# Sent batch 275 with 20/20 records from Producer-A
# Sent batch 276 with 20/20 records from Producer-A
# Sent batch 277 with 20/20 records from Producer-A
# Sent batch 278 with 20/20 records from Producer-A
# Sent batch 279 with 20/20 records from Producer-A
# /tmp/ipykernel_1922/2803335257.py:17: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   batch_df['event_date'] = pd.to_datetime(batch_df['timestamp']).dt.date.astype(str)
# Sent batch 280 with 20/20 records from Producer-A
# Sent batch 281 with 20/20 records from Producer-A
# Sent batch 282 with 20/20 records from Producer-A
# Sent batch 283 with 20/20 records from Producer-A
# Sent batch 284 with 20/20 records from Producer-A
# Sent batch 285 with 20/20 records from Producer-A
# Sent batch 286 with 20/20 records from Producer-A
# Sent batch 287 with 20/20 records from Producer-A
# Sent batch 288 with 20/20 records from Producer-A
# Sent batch 289 with 20/20 records from Producer-A
# Sent batch 290 with 20/20 records from Producer-A
# Sent batch 291 with 20/20 records from Producer-A
# Sent batch 292 with 20/20 records from Producer-A
# Sent batch 293 with 20/20 records from Producer-A
# Sent batch 294 with 20/20 records from Producer-A
# Sent batch 295 with 20/20 records from Producer-A
# Sent batch 296 with 20/20 records from Producer-A
# Sent batch 297 with 20/20 records from Producer-A
# Sent batch 298 with 20/20 records from Producer-A
# Sent batch 299 with 20/20 records from Producer-A
# Sent batch 300 with 20/20 records from Producer-A
# Sent batch 301 with 20/20 records from Producer-A
# Sent batch 302 with 20/20 records from Producer-A
# Sent batch 303 with 20/20 records from Producer-A
# Sent batch 304 with 20/20 records from Producer-A
# Sent batch 305 with 20/20 records from Producer-A
# Sent batch 306 with 20/20 records from Producer-A
# Sent batch 307 with 20/20 records from Producer-A
# Sent batch 308 with 20/20 records from Producer-A
# Sent batch 309 with 20/20 records from Producer-A
# Sent batch 310 with 20/20 records from Producer-A
# Sent batch 311 with 20/20 records from Producer-A
# Sent batch 312 with 20/20 records from Producer-A
# Sent batch 313 with 20/20 records from Producer-A
# Sent batch 314 with 20/20 records from Producer-A
# Sent batch 315 with 20/20 records from Producer-A
# Sent batch 316 with 20/20 records from Producer-A
# Sent batch 317 with 20/20 records from Producer-A
# Sent batch 318 with 20/20 records from Producer-A
# Sent batch 319 with 20/20 records from Producer-A
# Sent batch 320 with 20/20 records from Producer-A
# Sent batch 321 with 20/20 records from Producer-A
# Sent batch 322 with 20/20 records from Producer-A
# Sent batch 323 with 20/20 records from Producer-A
# Sent batch 324 with 20/20 records from Producer-A
# Sent batch 325 with 20/20 records from Producer-A
# Sent batch 326 with 20/20 records from Producer-A
# Sent batch 327 with 20/20 records from Producer-A
# Sent batch 328 with 20/20 records from Producer-A
# Sent batch 329 with 20/20 records from Producer-A
# Sent batch 330 with 20/20 records from Producer-A
# Sent batch 331 with 20/20 records from Producer-A
# Sent batch 332 with 20/20 records from Producer-A
# Sent batch 333 with 20/20 records from Producer-A
# Sent batch 334 with 20/20 records from Producer-A
# Sent batch 335 with 20/20 records from Producer-A
# Sent batch 336 with 20/20 records from Producer-A
# Sent batch 337 with 20/20 records from Producer-A
# Sent batch 338 with 20/20 records from Producer-A
# Sent batch 339 with 20/20 records from Producer-A
# Sent batch 340 with 20/20 records from Producer-A
# Sent batch 341 with 20/20 records from Producer-A
# Sent batch 342 with 20/20 records from Producer-A
# Sent batch 343 with 20/20 records from Producer-A
# Sent batch 344 with 20/20 records from Producer-A
# Sent batch 345 with 20/20 records from Producer-A
# Sent batch 346 with 20/20 records from Producer-A
# Sent batch 347 with 20/20 records from Producer-A
# Sent batch 348 with 20/20 records from Producer-A
# Sent batch 349 with 20/20 records from Producer-A
# Sent batch 350 with 20/20 records from Producer-A
# Sent batch 351 with 20/20 records from Producer-A
# Sent batch 352 with 20/20 records from Producer-A
# Sent batch 353 with 20/20 records from Producer-A
# Sent batch 354 with 20/20 records from Producer-A
# Sent batch 355 with 20/20 records from Producer-A
# Sent batch 356 with 20/20 records from Producer-A
# Sent batch 357 with 20/20 records from Producer-A
# Sent batch 358 with 20/20 records from Producer-A
# Sent batch 359 with 20/20 records from Producer-A
# Sent batch 360 with 20/20 records from Producer-A
# Sent batch 361 with 20/20 records from Producer-A
# Sent batch 362 with 20/20 records from Producer-A
# Sent batch 363 with 20/20 records from Producer-A
# Sent batch 364 with 20/20 records from Producer-A
# Sent batch 365 with 20/20 records from Producer-A
# Sent batch 366 with 20/20 records from Producer-A
# Sent batch 367 with 20/20 records from Producer-A
# Sent batch 368 with 20/20 records from Producer-A
# Sent batch 369 with 20/20 records from Producer-A
# Sent batch 370 with 20/20 records from Producer-A
# Sent batch 371 with 20/20 records from Producer-A
# Sent batch 372 with 20/20 records from Producer-A
# Sent batch 373 with 20/20 records from Producer-A
# Sent batch 374 with 20/20 records from Producer-A
# Sent batch 375 with 20/20 records from Producer-A
# Sent batch 376 with 20/20 records from Producer-A
# Sent batch 377 with 20/20 records from Producer-A
# Sent batch 378 with 20/20 records from Producer-A
# Sent batch 379 with 20/20 records from Producer-A
# Sent batch 380 with 20/20 records from Producer-A
# Sent batch 381 with 20/20 records from Producer-A
# Sent batch 382 with 20/20 records from Producer-A
# Sent batch 383 with 20/20 records from Producer-A
# Sent batch 384 with 20/20 records from Producer-A
# Sent batch 385 with 20/20 records from Producer-A
# Sent batch 386 with 20/20 records from Producer-A
# Sent batch 387 with 20/20 records from Producer-A
# Sent batch 388 with 20/20 records from Producer-A
# Sent batch 389 with 20/20 records from Producer-A
# Sent batch 390 with 20/20 records from Producer-A
# Sent batch 391 with 20/20 records from Producer-A
# Sent batch 392 with 20/20 records from Producer-A
# Sent batch 393 with 20/20 records from Producer-A
# Sent batch 394 with 20/20 records from Producer-A
# Sent batch 395 with 20/20 records from Producer-A
# Sent batch 396 with 20/20 records from Producer-A
# Sent batch 397 with 20/20 records from Producer-A
# Sent batch 398 with 20/20 records from Producer-A
# Sent batch 399 with 20/20 records from Producer-A
# Sent batch 400 with 20/20 records from Producer-A
# Sent batch 401 with 20/20 records from Producer-A
# Sent batch 402 with 20/20 records from Producer-A
# Sent batch 403 with 20/20 records from Producer-A
# Sent batch 404 with 20/20 records from Producer-A
# Sent batch 405 with 20/20 records from Producer-A
# Sent batch 406 with 20/20 records from Producer-A
# Sent batch 407 with 20/20 records from Producer-A
# Sent batch 408 with 20/20 records from Producer-A
# Sent batch 409 with 20/20 records from Producer-A
# Sent batch 410 with 20/20 records from Producer-A
# Sent batch 411 with 20/20 records from Producer-A
# Sent batch 412 with 20/20 records from Producer-A
# Sent batch 413 with 20/20 records from Producer-A
# Sent batch 414 with 20/20 records from Producer-A
# Sent batch 415 with 20/20 records from Producer-A
# Sent batch 416 with 20/20 records from Producer-A
# Sent batch 417 with 20/20 records from Producer-A
# Sent batch 418 with 20/20 records from Producer-A
# Sent batch 419 with 20/20 records from Producer-A
# Sent batch 420 with 20/20 records from Producer-A
# Sent batch 421 with 20/20 records from Producer-A
# Sent batch 422 with 20/20 records from Producer-A
# Sent batch 423 with 20/20 records from Producer-A
# Sent batch 424 with 20/20 records from Producer-A
# Sent batch 425 with 20/20 records from Producer-A
# Sent batch 426 with 20/20 records from Producer-A
# Sent batch 427 with 20/20 records from Producer-A
# Sent batch 428 with 20/20 records from Producer-A
# Sent batch 429 with 20/20 records from Producer-A
# Sent batch 430 with 20/20 records from Producer-A
# Sent batch 431 with 20/20 records from Producer-A
# Sent batch 432 with 20/20 records from Producer-A
# Sent batch 433 with 20/20 records from Producer-A
# Sent batch 434 with 20/20 records from Producer-A
# Sent batch 435 with 20/20 records from Producer-A
# Sent batch 436 with 20/20 records from Producer-A
# Sent batch 437 with 20/20 records from Producer-A
# Sent batch 438 with 20/20 records from Producer-A
# Sent batch 439 with 20/20 records from Producer-A
# Sent batch 440 with 20/20 records from Producer-A
# Sent batch 441 with 20/20 records from Producer-A
# Sent batch 442 with 20/20 records from Producer-A
# Sent batch 443 with 20/20 records from Producer-A
# Sent batch 444 with 20/20 records from Producer-A
# Sent batch 445 with 20/20 records from Producer-A
# Sent batch 446 with 20/20 records from Producer-A
# Sent batch 447 with 20/20 records from Producer-A
# Sent batch 448 with 20/20 records from Producer-A
# Sent batch 449 with 20/20 records from Producer-A
# Sent batch 450 with 20/20 records from Producer-A
# Sent batch 451 with 20/20 records from Producer-A
# Sent batch 452 with 20/20 records from Producer-A
# Sent batch 453 with 20/20 records from Producer-A
# Sent batch 454 with 20/20 records from Producer-A
# Sent batch 455 with 20/20 records from Producer-A
# Sent batch 456 with 20/20 records from Producer-A
# Sent batch 457 with 20/20 records from Producer-A
# Sent batch 458 with 20/20 records from Producer-A
# Sent batch 459 with 20/20 records from Producer-A
# Sent batch 460 with 20/20 records from Producer-A
# Sent batch 461 with 20/20 records from Producer-A
# Sent batch 462 with 20/20 records from Producer-A
# Sent batch 463 with 20/20 records from Producer-A
# Sent batch 464 with 20/20 records from Producer-A
# Sent batch 465 with 20/20 records from Producer-A
# Sent batch 466 with 20/20 records from Producer-A
# Sent batch 467 with 20/20 records from Producer-A
# Sent batch 468 with 20/20 records from Producer-A
# Sent batch 469 with 20/20 records from Producer-A
# Sent batch 470 with 20/20 records from Producer-A
# Sent batch 471 with 20/20 records from Producer-A
# Sent batch 472 with 20/20 records from Producer-A
# Sent batch 473 with 20/20 records from Producer-A
# Producer interrupted by user
# Kafka producer closed
