# %% [markdown]
# # Camera Event Producer B
#
# This notebook implements a Kafka producer that reads data from `camera_event_B.csv` and sends it to a Kafka topic in batches.

# %%
# Import required libraries
import pandas as pd
import json
import time
from kafka import KafkaProducer
from datetime import datetime
import os

# %%
# Configuration parameters
KAFKA_BOOTSTRAP_SERVERS = '172.25.240.1:9092'
KAFKA_TOPIC = 'camera_events'
BATCH_INTERVAL = 5  # seconds between each batch
PRODUCER_ID = 'Producer-B'
CSV_FILE = 'camera_event_B.csv'  # Path to the CSV file

# Check if the file exists, otherwise use a default path for testing
if not os.path.exists(CSV_FILE):
    CSV_FILE = '/home/student/Assignment 2/temp_data/data/camera_event_B.csv'  # Adjust path as needed for testing
    if not os.path.exists(CSV_FILE):
        print(f"Warning: {CSV_FILE} not found. Please ensure the file exists.")

# %%
# Function to load data from CSV file
def load_data(file_path):
    try:
        df = pd.read_csv(file_path)
        print(f"Successfully loaded {len(df)} records from {file_path}")
        return df
    except Exception as e:
        print(f"Error loading data: {e}")
        return None

# %%
# Function to initialize Kafka producer
def create_kafka_producer():
    try:
        producer = KafkaProducer(
            bootstrap_servers=KAFKA_BOOTSTRAP_SERVERS,
            value_serializer=lambda v: json.dumps(v).encode('utf-8'),
            key_serializer=lambda k: k.encode('utf-8') if k else None
        )
        print("Kafka producer initialized successfully")
        return producer
    except Exception as e:
        print(f"Error creating Kafka producer: {e}")
        return None

# %%
# Function to process and send data in batches
def process_and_send_batches(producer, df):
    # Get unique batch IDs and sort them
    batch_ids = sorted(df['batch_id'].unique())
    
    for batch_id in batch_ids:
        # Get records for current batch
        batch_df = df[df['batch_id'] == batch_id].copy()
        
        # Add producer information
        batch_df['producer_info'] = PRODUCER_ID
        
        # Add current processing timestamp
        batch_df['processing_timestamp'] = datetime.now().isoformat()
        
        # Extract event date from timestamp
        batch_df['event_date'] = pd.to_datetime(batch_df['timestamp']).dt.date.astype(str)
        
        # Convert to list of dictionaries for sending
        batch_records = batch_df.to_dict('records')
        
        # Send each record in the batch to Kafka
        sent_count = 0
        for record in batch_records:
            try:
                # Use car_plate as the key for partitioning
                key = record['car_plate']
                # Send to Kafka topic
                producer.send(KAFKA_TOPIC, key=key, value=record)
                sent_count += 1
            except Exception as e:
                print(f"Error sending record: {e}")
        
        # Flush to ensure all messages are sent before waiting
        producer.flush()
        
        print(f"Sent batch {batch_id} with {sent_count}/{len(batch_records)} records from {PRODUCER_ID}")
        
        # Wait for the specified interval before sending the next batch
        time.sleep(BATCH_INTERVAL)

# %%
# Main execution function
def run_producer():
    # Load data from CSV
    df = load_data(CSV_FILE)
    if df is None:
        print("Failed to load data. Exiting.")
        return
    
    # Create Kafka producer
    producer = create_kafka_producer()
    if producer is None:
        print("Failed to create Kafka producer. Exiting.")
        return
    
    try:
        # Process and send data in batches
        print(f"Starting to send data from {PRODUCER_ID} at {datetime.now()}")
        process_and_send_batches(producer, df)
        print(f"Finished sending all data from {PRODUCER_ID} at {datetime.now()}")
    except KeyboardInterrupt:
        print("Producer interrupted by user")
    except Exception as e:
        print(f"Error in producer: {e}")
    finally:
        # Close producer
        if producer is not None:
            producer.close()
            print("Kafka producer closed")

# %%
# Run the producer
if __name__ == "__main__":
    run_producer()
# Out:
# Successfully loaded 556340 records from /home/student/Assignment 2/temp_data/data/camera_event_B.csv
# Kafka producer initialized successfully
# Starting to send data from Producer-B at 2025-05-29 10:08:07.278724
# Sent batch 1 with 5/5 records from Producer-B
# Sent batch 2 with 1/1 records from Producer-B
# Sent batch 3 with 1/1 records from Producer-B
# Sent batch 4 with 4/4 records from Producer-B
# Sent batch 5 with 4/4 records from Producer-B
# Sent batch 6 with 2/2 records from Producer-B
# Sent batch 7 with 3/3 records from Producer-B
# Sent batch 8 with 1/1 records from Producer-B
# Sent batch 9 with 2/2 records from Producer-B
# Sent batch 10 with 2/2 records from Producer-B
# Sent batch 11 with 1/1 records from Producer-B
# Sent batch 12 with 1/1 records from Producer-B
# Sent batch 13 with 1/1 records from Producer-B
# Sent batch 14 with 1/1 records from Producer-B
# Sent batch 15 with 2/2 records from Producer-B
# Sent batch 16 with 2/2 records from Producer-B
# Sent batch 17 with 1/1 records from Producer-B
# Sent batch 18 with 1/1 records from Producer-B
# Sent batch 19 with 4/4 records from Producer-B
# Sent batch 20 with 2/2 records from Producer-B
# Sent batch 21 with 1/1 records from Producer-B
# Sent batch 22 with 3/3 records from Producer-B
# Sent batch 23 with 1/1 records from Producer-B
# Sent batch 24 with 1/1 records from Producer-B
# Sent batch 25 with 2/2 records from Producer-B
# Sent batch 26 with 2/2 records from Producer-B
# Sent batch 27 with 1/1 records from Producer-B
# Sent batch 28 with 1/1 records from Producer-B
# Sent batch 29 with 1/1 records from Producer-B
# Sent batch 30 with 2/2 records from Producer-B
# Sent batch 31 with 3/3 records from Producer-B
# Sent batch 32 with 1/1 records from Producer-B
# Sent batch 33 with 1/1 records from Producer-B
# Sent batch 34 with 2/2 records from Producer-B
# Sent batch 35 with 3/3 records from Producer-B
# Sent batch 36 with 1/1 records from Producer-B
# Sent batch 37 with 4/4 records from Producer-B
# Sent batch 38 with 1/1 records from Producer-B
# Sent batch 39 with 2/2 records from Producer-B
# Sent batch 40 with 1/1 records from Producer-B
# Sent batch 41 with 1/1 records from Producer-B
# Sent batch 42 with 4/4 records from Producer-B
# Sent batch 43 with 1/1 records from Producer-B
# Sent batch 44 with 1/1 records from Producer-B
# Sent batch 45 with 2/2 records from Producer-B
# Sent batch 46 with 1/1 records from Producer-B
# Sent batch 47 with 1/1 records from Producer-B
# Sent batch 48 with 3/3 records from Producer-B
# Sent batch 49 with 3/3 records from Producer-B
# Sent batch 50 with 4/4 records from Producer-B
# Sent batch 51 with 2/2 records from Producer-B
# Sent batch 52 with 6/6 records from Producer-B
# Sent batch 53 with 1/1 records from Producer-B
# Sent batch 54 with 1/1 records from Producer-B
# Sent batch 55 with 5/5 records from Producer-B
# Sent batch 56 with 1/1 records from Producer-B
# Sent batch 57 with 1/1 records from Producer-B
# Sent batch 58 with 2/2 records from Producer-B
# Sent batch 59 with 2/2 records from Producer-B
# Sent batch 60 with 1/1 records from Producer-B
# Sent batch 61 with 2/2 records from Producer-B
# Sent batch 62 with 4/4 records from Producer-B
# Sent batch 63 with 2/2 records from Producer-B
# Sent batch 64 with 1/1 records from Producer-B
# Sent batch 65 with 1/1 records from Producer-B
# Sent batch 66 with 1/1 records from Producer-B
# Sent batch 67 with 1/1 records from Producer-B
# Sent batch 68 with 2/2 records from Producer-B
# Sent batch 69 with 1/1 records from Producer-B
# Sent batch 70 with 2/2 records from Producer-B
# Sent batch 71 with 1/1 records from Producer-B
# Sent batch 72 with 3/3 records from Producer-B
# Sent batch 73 with 1/1 records from Producer-B
# Sent batch 74 with 3/3 records from Producer-B
# Sent batch 75 with 2/2 records from Producer-B
# Sent batch 76 with 2/2 records from Producer-B
# Sent batch 77 with 3/3 records from Producer-B
# Sent batch 78 with 1/1 records from Producer-B
# Sent batch 79 with 2/2 records from Producer-B
# Sent batch 80 with 2/2 records from Producer-B
# Sent batch 81 with 2/2 records from Producer-B
# Sent batch 82 with 1/1 records from Producer-B
# Sent batch 83 with 1/1 records from Producer-B
# Sent batch 84 with 3/3 records from Producer-B
# Sent batch 85 with 1/1 records from Producer-B
# Sent batch 86 with 1/1 records from Producer-B
# Sent batch 87 with 3/3 records from Producer-B
# Sent batch 88 with 3/3 records from Producer-B
# Sent batch 89 with 2/2 records from Producer-B
# Sent batch 90 with 3/3 records from Producer-B
# Sent batch 91 with 4/4 records from Producer-B
# Sent batch 92 with 1/1 records from Producer-B
# Sent batch 93 with 2/2 records from Producer-B
# Sent batch 94 with 2/2 records from Producer-B
# Sent batch 95 with 2/2 records from Producer-B
# Sent batch 96 with 1/1 records from Producer-B
# Sent batch 97 with 2/2 records from Producer-B
# Sent batch 98 with 2/2 records from Producer-B
# Sent batch 99 with 3/3 records from Producer-B
# Sent batch 100 with 2/2 records from Producer-B
# Sent batch 101 with 1/1 records from Producer-B
# Sent batch 102 with 1/1 records from Producer-B
# Sent batch 103 with 1/1 records from Producer-B
# Sent batch 104 with 1/1 records from Producer-B
# Sent batch 105 with 2/2 records from Producer-B
# Sent batch 106 with 2/2 records from Producer-B
# Sent batch 107 with 1/1 records from Producer-B
# Sent batch 108 with 1/1 records from Producer-B
# Sent batch 109 with 3/3 records from Producer-B
# Sent batch 110 with 2/2 records from Producer-B
# Sent batch 111 with 1/1 records from Producer-B
# Sent batch 112 with 1/1 records from Producer-B
# Sent batch 113 with 2/2 records from Producer-B
# Sent batch 114 with 5/5 records from Producer-B
# Sent batch 115 with 2/2 records from Producer-B
# Sent batch 116 with 3/3 records from Producer-B
# Sent batch 117 with 2/2 records from Producer-B
# Sent batch 118 with 1/1 records from Producer-B
# Sent batch 119 with 1/1 records from Producer-B
# Sent batch 120 with 5/5 records from Producer-B
# Sent batch 121 with 1/1 records from Producer-B
# Sent batch 122 with 3/3 records from Producer-B
# Sent batch 123 with 2/2 records from Producer-B
# Sent batch 124 with 1/1 records from Producer-B
# Sent batch 125 with 2/2 records from Producer-B
# Sent batch 126 with 1/1 records from Producer-B
# Sent batch 127 with 1/1 records from Producer-B
# Sent batch 128 with 1/1 records from Producer-B
# Sent batch 129 with 3/3 records from Producer-B
# Sent batch 130 with 4/4 records from Producer-B
# Sent batch 131 with 3/3 records from Producer-B
# Sent batch 132 with 1/1 records from Producer-B
# Sent batch 133 with 4/4 records from Producer-B
# Sent batch 134 with 1/1 records from Producer-B
# Sent batch 135 with 1/1 records from Producer-B
# Sent batch 136 with 1/1 records from Producer-B
# Sent batch 137 with 1/1 records from Producer-B
# Sent batch 138 with 1/1 records from Producer-B
# Sent batch 139 with 2/2 records from Producer-B
# Sent batch 140 with 1/1 records from Producer-B
# Sent batch 141 with 1/1 records from Producer-B
# Sent batch 142 with 3/3 records from Producer-B
# Sent batch 143 with 2/2 records from Producer-B
# Sent batch 144 with 1/1 records from Producer-B
# Sent batch 145 with 3/3 records from Producer-B
# Sent batch 146 with 2/2 records from Producer-B
# Sent batch 147 with 3/3 records from Producer-B
# Sent batch 148 with 1/1 records from Producer-B
# Sent batch 149 with 1/1 records from Producer-B
# Sent batch 150 with 4/4 records from Producer-B
# Sent batch 151 with 2/2 records from Producer-B
# Sent batch 152 with 2/2 records from Producer-B
# Sent batch 153 with 2/2 records from Producer-B
# Sent batch 154 with 5/5 records from Producer-B
# Sent batch 155 with 2/2 records from Producer-B
# Sent batch 156 with 2/2 records from Producer-B
# Sent batch 157 with 1/1 records from Producer-B
# Sent batch 158 with 2/2 records from Producer-B
# Sent batch 159 with 1/1 records from Producer-B
# Sent batch 160 with 3/3 records from Producer-B
# Sent batch 161 with 1/1 records from Producer-B
# Sent batch 162 with 1/1 records from Producer-B
# Sent batch 163 with 4/4 records from Producer-B
# Sent batch 164 with 4/4 records from Producer-B
# Sent batch 165 with 3/3 records from Producer-B
# Sent batch 166 with 2/2 records from Producer-B
# Sent batch 167 with 1/1 records from Producer-B
# Sent batch 168 with 1/1 records from Producer-B
# Sent batch 169 with 2/2 records from Producer-B
# Sent batch 170 with 1/1 records from Producer-B
# Sent batch 171 with 5/5 records from Producer-B
# Sent batch 172 with 1/1 records from Producer-B
# Sent batch 173 with 1/1 records from Producer-B
# Sent batch 174 with 3/3 records from Producer-B
# Sent batch 175 with 1/1 records from Producer-B
# Sent batch 176 with 2/2 records from Producer-B
# Sent batch 177 with 2/2 records from Producer-B
# Sent batch 178 with 3/3 records from Producer-B
# Sent batch 179 with 4/4 records from Producer-B
# Sent batch 180 with 1/1 records from Producer-B
# Sent batch 181 with 1/1 records from Producer-B
# Sent batch 182 with 3/3 records from Producer-B
# Sent batch 183 with 1/1 records from Producer-B
# Sent batch 184 with 1/1 records from Producer-B
# Sent batch 185 with 1/1 records from Producer-B
# Sent batch 186 with 1/1 records from Producer-B
# Sent batch 187 with 1/1 records from Producer-B
# Sent batch 188 with 2/2 records from Producer-B
# Sent batch 189 with 3/3 records from Producer-B
# Sent batch 190 with 2/2 records from Producer-B
# Sent batch 191 with 2/2 records from Producer-B
# Sent batch 192 with 1/1 records from Producer-B
# Sent batch 193 with 3/3 records from Producer-B
# Sent batch 194 with 1/1 records from Producer-B
# Sent batch 195 with 4/4 records from Producer-B
# Sent batch 196 with 1/1 records from Producer-B
# Sent batch 197 with 1/1 records from Producer-B
# Sent batch 198 with 2/2 records from Producer-B
# Sent batch 199 with 3/3 records from Producer-B
# Sent batch 200 with 1/1 records from Producer-B
# Sent batch 201 with 1/1 records from Producer-B
# Sent batch 202 with 2/2 records from Producer-B
# Sent batch 203 with 1/1 records from Producer-B
# Sent batch 204 with 3/3 records from Producer-B
# Sent batch 205 with 1/1 records from Producer-B
# Sent batch 206 with 4/4 records from Producer-B
# Sent batch 207 with 2/2 records from Producer-B
# Sent batch 208 with 1/1 records from Producer-B
# Sent batch 209 with 1/1 records from Producer-B
# Sent batch 210 with 1/1 records from Producer-B
# Sent batch 211 with 3/3 records from Producer-B
# Sent batch 212 with 3/3 records from Producer-B
# Sent batch 213 with 1/1 records from Producer-B
# Sent batch 214 with 1/1 records from Producer-B
# Sent batch 215 with 2/2 records from Producer-B
# Sent batch 216 with 1/1 records from Producer-B
# Sent batch 217 with 3/3 records from Producer-B
# Sent batch 218 with 1/1 records from Producer-B
# Sent batch 219 with 1/1 records from Producer-B
# Sent batch 220 with 3/3 records from Producer-B
# Sent batch 221 with 3/3 records from Producer-B
# Sent batch 222 with 1/1 records from Producer-B
# Sent batch 223 with 5/5 records from Producer-B
# Sent batch 224 with 2/2 records from Producer-B
# Sent batch 225 with 1/1 records from Producer-B
# Sent batch 226 with 4/4 records from Producer-B
# Sent batch 227 with 3/3 records from Producer-B
# Sent batch 228 with 1/1 records from Producer-B
# Sent batch 229 with 1/1 records from Producer-B
# Sent batch 230 with 1/1 records from Producer-B
# Sent batch 231 with 4/4 records from Producer-B
# Sent batch 232 with 3/3 records from Producer-B
# Sent batch 233 with 1/1 records from Producer-B
# Sent batch 234 with 5/5 records from Producer-B
# Sent batch 235 with 2/2 records from Producer-B
# Sent batch 236 with 2/2 records from Producer-B
# Sent batch 237 with 2/2 records from Producer-B
# Sent batch 238 with 2/2 records from Producer-B
# Sent batch 239 with 2/2 records from Producer-B
# Sent batch 240 with 2/2 records from Producer-B
# Sent batch 241 with 4/4 records from Producer-B
# Sent batch 242 with 1/1 records from Producer-B
# Sent batch 243 with 2/2 records from Producer-B
# Sent batch 244 with 3/3 records from Producer-B
# Sent batch 245 with 1/1 records from Producer-B
# Sent batch 246 with 1/1 records from Producer-B
# Sent batch 247 with 1/1 records from Producer-B
# Sent batch 248 with 1/1 records from Producer-B
# Sent batch 249 with 1/1 records from Producer-B
# Sent batch 250 with 1/1 records from Producer-B
# Sent batch 251 with 1/1 records from Producer-B
# Sent batch 252 with 5/5 records from Producer-B
# Sent batch 253 with 2/2 records from Producer-B
# Sent batch 254 with 2/2 records from Producer-B
# Sent batch 255 with 2/2 records from Producer-B
# Sent batch 256 with 1/1 records from Producer-B
# Sent batch 257 with 1/1 records from Producer-B
# Sent batch 258 with 3/3 records from Producer-B
# Sent batch 259 with 2/2 records from Producer-B
# Sent batch 260 with 1/1 records from Producer-B
# Sent batch 261 with 2/2 records from Producer-B
# Sent batch 262 with 2/2 records from Producer-B
# Sent batch 263 with 1/1 records from Producer-B
# Sent batch 264 with 1/1 records from Producer-B
# Sent batch 265 with 3/3 records from Producer-B
# Sent batch 266 with 2/2 records from Producer-B
# Sent batch 267 with 2/2 records from Producer-B
# Sent batch 268 with 2/2 records from Producer-B
# Sent batch 269 with 1/1 records from Producer-B
# Sent batch 270 with 2/2 records from Producer-B
# Sent batch 271 with 2/2 records from Producer-B
# Sent batch 272 with 2/2 records from Producer-B
# Sent batch 273 with 3/3 records from Producer-B
# Sent batch 274 with 1/1 records from Producer-B
# Sent batch 275 with 2/2 records from Producer-B
# Sent batch 276 with 2/2 records from Producer-B
# Sent batch 277 with 1/1 records from Producer-B
# Sent batch 278 with 1/1 records from Producer-B
# Sent batch 279 with 2/2 records from Producer-B
# Sent batch 280 with 4/4 records from Producer-B
# Sent batch 281 with 2/2 records from Producer-B
# Sent batch 282 with 3/3 records from Producer-B
# Sent batch 283 with 1/1 records from Producer-B
# Sent batch 284 with 1/1 records from Producer-B
# Sent batch 285 with 2/2 records from Producer-B
# Sent batch 286 with 1/1 records from Producer-B
# Sent batch 287 with 1/1 records from Producer-B
# Sent batch 288 with 3/3 records from Producer-B
# Sent batch 289 with 2/2 records from Producer-B
# Sent batch 290 with 2/2 records from Producer-B
# Sent batch 291 with 2/2 records from Producer-B
# Sent batch 292 with 1/1 records from Producer-B
# Sent batch 293 with 2/2 records from Producer-B
# Sent batch 294 with 1/1 records from Producer-B
# Sent batch 295 with 1/1 records from Producer-B
# Sent batch 296 with 3/3 records from Producer-B
# Sent batch 297 with 1/1 records from Producer-B
# Sent batch 298 with 1/1 records from Producer-B
# Sent batch 299 with 2/2 records from Producer-B
# Sent batch 300 with 1/1 records from Producer-B
# Sent batch 301 with 4/4 records from Producer-B
# Sent batch 302 with 2/2 records from Producer-B
# Sent batch 303 with 1/1 records from Producer-B
# Sent batch 304 with 2/2 records from Producer-B
# Sent batch 305 with 2/2 records from Producer-B
# Sent batch 306 with 2/2 records from Producer-B
# Sent batch 307 with 1/1 records from Producer-B
# Sent batch 308 with 1/1 records from Producer-B
# Sent batch 309 with 2/2 records from Producer-B
# Sent batch 310 with 3/3 records from Producer-B
# Sent batch 311 with 1/1 records from Producer-B
# Sent batch 312 with 1/1 records from Producer-B
# Sent batch 313 with 1/1 records from Producer-B
# Sent batch 314 with 1/1 records from Producer-B
# Sent batch 315 with 1/1 records from Producer-B
# Sent batch 316 with 1/1 records from Producer-B
# Sent batch 317 with 1/1 records from Producer-B
# Sent batch 318 with 3/3 records from Producer-B
# Sent batch 319 with 1/1 records from Producer-B
# Sent batch 320 with 1/1 records from Producer-B
# Sent batch 321 with 2/2 records from Producer-B
# Sent batch 322 with 3/3 records from Producer-B
# Sent batch 323 with 3/3 records from Producer-B
# Sent batch 324 with 4/4 records from Producer-B
# Sent batch 325 with 1/1 records from Producer-B
# Sent batch 326 with 1/1 records from Producer-B
# Sent batch 327 with 2/2 records from Producer-B
# Sent batch 328 with 1/1 records from Producer-B
# Sent batch 329 with 2/2 records from Producer-B
# Sent batch 330 with 1/1 records from Producer-B
# Sent batch 331 with 1/1 records from Producer-B
# Sent batch 332 with 1/1 records from Producer-B
# Sent batch 333 with 2/2 records from Producer-B
# Sent batch 334 with 2/2 records from Producer-B
# Sent batch 335 with 3/3 records from Producer-B
# Sent batch 336 with 1/1 records from Producer-B
# Sent batch 337 with 1/1 records from Producer-B
# Sent batch 338 with 4/4 records from Producer-B
# Sent batch 339 with 2/2 records from Producer-B
# Sent batch 340 with 2/2 records from Producer-B
# Sent batch 341 with 1/1 records from Producer-B
# Sent batch 342 with 1/1 records from Producer-B
# Sent batch 343 with 1/1 records from Producer-B
# Sent batch 344 with 1/1 records from Producer-B
# Sent batch 345 with 2/2 records from Producer-B
# Sent batch 346 with 1/1 records from Producer-B
# Sent batch 347 with 2/2 records from Producer-B
# Sent batch 348 with 1/1 records from Producer-B
# Sent batch 349 with 1/1 records from Producer-B
# Sent batch 350 with 1/1 records from Producer-B
# Sent batch 351 with 2/2 records from Producer-B
# Sent batch 352 with 3/3 records from Producer-B
# Sent batch 353 with 2/2 records from Producer-B
# Sent batch 354 with 3/3 records from Producer-B
# Sent batch 355 with 2/2 records from Producer-B
# Sent batch 356 with 2/2 records from Producer-B
# Sent batch 357 with 1/1 records from Producer-B
# Sent batch 358 with 1/1 records from Producer-B
# Sent batch 359 with 1/1 records from Producer-B
# Sent batch 360 with 1/1 records from Producer-B
# Sent batch 361 with 2/2 records from Producer-B
# Sent batch 362 with 1/1 records from Producer-B
# Sent batch 363 with 1/1 records from Producer-B
# Sent batch 364 with 3/3 records from Producer-B
# Sent batch 365 with 2/2 records from Producer-B
# Sent batch 366 with 1/1 records from Producer-B
# Sent batch 367 with 2/2 records from Producer-B
# Sent batch 368 with 1/1 records from Producer-B
# Sent batch 369 with 1/1 records from Producer-B
# Sent batch 370 with 3/3 records from Producer-B
# Sent batch 371 with 1/1 records from Producer-B
# Sent batch 372 with 1/1 records from Producer-B
# Sent batch 373 with 1/1 records from Producer-B
# Sent batch 374 with 1/1 records from Producer-B
# Sent batch 375 with 1/1 records from Producer-B
# Sent batch 376 with 1/1 records from Producer-B
# Sent batch 377 with 2/2 records from Producer-B
# Sent batch 378 with 5/5 records from Producer-B
# Sent batch 379 with 2/2 records from Producer-B
# Sent batch 380 with 2/2 records from Producer-B
# Sent batch 381 with 1/1 records from Producer-B
# Sent batch 382 with 4/4 records from Producer-B
# Sent batch 383 with 1/1 records from Producer-B
# Sent batch 384 with 1/1 records from Producer-B
# Sent batch 385 with 1/1 records from Producer-B
# Sent batch 386 with 1/1 records from Producer-B
# Sent batch 387 with 3/3 records from Producer-B
# Sent batch 388 with 3/3 records from Producer-B
# Sent batch 389 with 3/3 records from Producer-B
# Sent batch 390 with 3/3 records from Producer-B
# Sent batch 391 with 1/1 records from Producer-B
# Sent batch 392 with 3/3 records from Producer-B
# Sent batch 393 with 3/3 records from Producer-B
# Sent batch 394 with 1/1 records from Producer-B
# Sent batch 395 with 2/2 records from Producer-B
# Sent batch 396 with 1/1 records from Producer-B
# Sent batch 397 with 3/3 records from Producer-B
# Sent batch 398 with 2/2 records from Producer-B
# Sent batch 399 with 1/1 records from Producer-B
# Sent batch 400 with 1/1 records from Producer-B
# Sent batch 401 with 3/3 records from Producer-B
# Sent batch 402 with 3/3 records from Producer-B
# Sent batch 403 with 1/1 records from Producer-B
# Sent batch 404 with 1/1 records from Producer-B
# Sent batch 405 with 5/5 records from Producer-B
# Sent batch 406 with 1/1 records from Producer-B
# Sent batch 407 with 3/3 records from Producer-B
# Sent batch 408 with 1/1 records from Producer-B
# Sent batch 409 with 2/2 records from Producer-B
# Sent batch 410 with 1/1 records from Producer-B
# Sent batch 411 with 2/2 records from Producer-B
# Sent batch 412 with 1/1 records from Producer-B
# Sent batch 413 with 1/1 records from Producer-B
# Sent batch 414 with 3/3 records from Producer-B
# Sent batch 415 with 1/1 records from Producer-B
# Sent batch 416 with 2/2 records from Producer-B
# Sent batch 417 with 1/1 records from Producer-B
# Sent batch 418 with 2/2 records from Producer-B
# Sent batch 419 with 1/1 records from Producer-B
# Sent batch 420 with 3/3 records from Producer-B
# Sent batch 421 with 3/3 records from Producer-B
# Sent batch 422 with 2/2 records from Producer-B
# Sent batch 423 with 1/1 records from Producer-B
# Sent batch 424 with 2/2 records from Producer-B
# Sent batch 425 with 2/2 records from Producer-B
# Sent batch 426 with 1/1 records from Producer-B
# Sent batch 427 with 2/2 records from Producer-B
# Sent batch 428 with 1/1 records from Producer-B
# Sent batch 429 with 3/3 records from Producer-B
# Sent batch 430 with 1/1 records from Producer-B
# Sent batch 431 with 2/2 records from Producer-B
# Sent batch 432 with 2/2 records from Producer-B
# Sent batch 433 with 1/1 records from Producer-B
# Sent batch 434 with 4/4 records from Producer-B
# Sent batch 435 with 3/3 records from Producer-B
# Sent batch 436 with 1/1 records from Producer-B
# Sent batch 437 with 3/3 records from Producer-B
# Sent batch 438 with 1/1 records from Producer-B
# Sent batch 439 with 1/1 records from Producer-B
# Sent batch 440 with 2/2 records from Producer-B
# Sent batch 441 with 1/1 records from Producer-B
# Sent batch 442 with 2/2 records from Producer-B
# Sent batch 443 with 1/1 records from Producer-B
# Sent batch 444 with 1/1 records from Producer-B
# Sent batch 445 with 1/1 records from Producer-B
# Sent batch 446 with 2/2 records from Producer-B
# Sent batch 447 with 1/1 records from Producer-B
# Sent batch 448 with 1/1 records from Producer-B
# Sent batch 449 with 1/1 records from Producer-B
# Sent batch 450 with 3/3 records from Producer-B
# Sent batch 451 with 1/1 records from Producer-B
# Sent batch 452 with 1/1 records from Producer-B
# Sent batch 453 with 3/3 records from Producer-B
# Sent batch 454 with 3/3 records from Producer-B
# Sent batch 455 with 1/1 records from Producer-B
# Sent batch 456 with 1/1 records from Producer-B
# Sent batch 457 with 3/3 records from Producer-B
# Sent batch 458 with 2/2 records from Producer-B
# Sent batch 459 with 1/1 records from Producer-B
# Sent batch 460 with 2/2 records from Producer-B
